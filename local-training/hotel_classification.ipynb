# %%
from google.cloud import bigquery

PROJECT_ID = "burner-neisincl"

client = bigquery.Client(project=PROJECT_ID)

query = """
SELECT COUNT(*) AS row_count
FROM `burner-neisincl.binary_classification_demo.hotel_clean`
"""

df = client.query(query).to_dataframe()
print(df)
# Out:
# /Users/neisincl/code/gcp-training/.venv/lib/python3.12/site-packages/google/cloud/bigquery/table.py:2082: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#    row_count
# 0     119390
